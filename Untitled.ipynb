# %% [markdown]
# # Florance Airbnb Analysis
#
# In this notebook we will try to analyse Florance Airbnb listing
#
#
#
# ## Table of Contents
#
# I. [Load the Data ](#Load-the-Data)<br>
# II. [Exploratory Data Analysis](#Exploratory-Data-Analysis)<br>
# III. [User-User Based Collaborative Filtering](#User-User)<br>
# IV. [Content Based Recommendations (EXTRA - NOT REQUIRED)](#Content-Recs)<br>
# V. [Matrix Factorization](#Matrix-Fact)<br>
# VI. [Extras & Concluding](#conclusions)

# %% [markdown]
# ### Load necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### <a class="anchor" id="Load-the-Data">Part I: Load the Data</a>

# %%
calendar = pd.read_csv("calendar.csv")
listings = pd.read_csv("listings.csv")
reviews = pd.read_csv("reviews.csv")
# Out:
# /home/mohammad/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (43,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0      285563  2019-06-22         f  $130.00        $130.00               1
# 1       24469  2019-06-22         t   $80.00         $80.00               2
# 2       24469  2019-06-23         t   $80.00         $80.00               2
# 3       24469  2019-06-24         t   $80.00         $80.00               2
# 4       24469  2019-06-25         t   $80.00         $80.00               2
#
#    maximum_nights
# 0              90
# 1             365
# 2             365
# 3             365
# 4             365

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  24469  https://www.airbnb.com/rooms/24469  20190622031149   2019-06-22
# 1  24470  https://www.airbnb.com/rooms/24470  20190622031149   2019-06-22
# 2  24471  https://www.airbnb.com/rooms/24471  20190622031149   2019-06-22
# 3  24472  https://www.airbnb.com/rooms/24472  20190622031149   2019-06-22
# 4  24807  https://www.airbnb.com/rooms/24807  20190622031149   2019-06-22
#
#                                   name  \
# 0  Fortezza/City Centre Modern Apt 2+2
# 1  Fortezza/City Centre Modern Apt 2+1
# 2  Fortezza/City Centre Modern Apt 4+2
# 3  Fortezza/City Centre Modern Apt 4+2
# 4  Beautiful Apartment Florence & WIFI
#
#                                              summary  \
# 0  Apartment, perfect for 2 people, wide, bright ...
# 1  Apartment, perfect for 2 people, can accommoda...
# 2  Perfect, big apartment for families or groups ...
# 3  Santa Maria Novella, perfect apartment for fam...
# 4  CLEANLINESS, COMFORT and QUIETNESS!! Our stren...
#
#                                                space  \
# 0  Located on the first floor of a 19th century t...
# 1  Located on the first floor of a 19th century t...
# 2  Located on the first floor of a 19th century t...
# 3  Located on the first floor of a 19th century t...
# 4  It's not a case if we have some 330 five star ...
#
#                                          description experiences_offered  \
# 0  Apartment, perfect for 2 people, wide, bright ...                none
# 1  Apartment, perfect for 2 people, can accommoda...                none
# 2  Perfect, big apartment for families or groups ...                none
# 3  Santa Maria Novella, perfect apartment for fam...                none
# 4  CLEANLINESS, COMFORT and QUIETNESS!! Our stren...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  In 10/15 minutes walking or with only one stop...  ...                t
# 1  In 10/15 minutes walking you will reach the hi...  ...                t
# 2  In 10/15 minutes walking you will reach the hi...  ...                t
# 3  In 10/15 minutes walking or with only one stop...  ...                t
# 4                                                NaN  ...                t
#
#   is_business_travel_ready cancellation_policy require_guest_profile_picture  \
# 0                        f        moderate_new                             f
# 1                        f        moderate_new                             f
# 2                        f        moderate_new                             f
# 3                        f        moderate_new                             f
# 4                        f        moderate_new                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               5
# 1                                f                               5
# 2                                f                               5
# 3                                f                               5
# 4                                f                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            5
# 1                                            5
# 2                                            5
# 3                                            5
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0                NaN
# 1                                            0               0.03
# 2                                            0                NaN
# 3                                            0               0.02
# 4                                            0               3.10
#
# [5 rows x 106 columns]

# %%
reviews.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0       24470     102982  2010-09-22        77244       Luciana
# 1       24470     124303  2010-10-22       233800         Steve
# 2       24470  440911489  2019-04-21    150908154         Paola
# 3       24472     340528  2011-06-28       239905       Michael
# 4       24472    1107562  2012-04-11      1207241        Daniel
#
#                                             comments
# 0  We loved to stay at Benedetta and Lorenzo apt....
# 1  A perfect place to spend a week. Amenities wer...
# 2  Buona posizione tranquilla e ottima accoglienz...
# 3  Lovely place. Its closeness to the train stati...
# 4  Loved this place! Benedetta and Lorenzo were g...

# %% [markdown]
# ### <a class="anchor" id="Exploratory-Data-Analysis">Part II: Exploratory Data Analysis</a>

# %%
listings.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
pd.set_option('display.max_columns', None)

# %%
when to rent to maximise revenue?
# Out:
# Object `revenue` not found.

# %%
when to rent to maximise revenue

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  24469  https://www.airbnb.com/rooms/24469  20190622031149   2019-06-22
# 1  24470  https://www.airbnb.com/rooms/24470  20190622031149   2019-06-22
# 2  24471  https://www.airbnb.com/rooms/24471  20190622031149   2019-06-22
# 3  24472  https://www.airbnb.com/rooms/24472  20190622031149   2019-06-22
# 4  24807  https://www.airbnb.com/rooms/24807  20190622031149   2019-06-22
#
#                                   name  \
# 0  Fortezza/City Centre Modern Apt 2+2
# 1  Fortezza/City Centre Modern Apt 2+1
# 2  Fortezza/City Centre Modern Apt 4+2
# 3  Fortezza/City Centre Modern Apt 4+2
# 4  Beautiful Apartment Florence & WIFI
#
#                                              summary  \
# 0  Apartment, perfect for 2 people, wide, bright ...
# 1  Apartment, perfect for 2 people, can accommoda...
# 2  Perfect, big apartment for families or groups ...
# 3  Santa Maria Novella, perfect apartment for fam...
# 4  CLEANLINESS, COMFORT and QUIETNESS!! Our stren...
#
#                                                space  \
# 0  Located on the first floor of a 19th century t...
# 1  Located on the first floor of a 19th century t...
# 2  Located on the first floor of a 19th century t...
# 3  Located on the first floor of a 19th century t...
# 4  It's not a case if we have some 330 five star ...
#
#                                          description experiences_offered  \
# 0  Apartment, perfect for 2 people, wide, bright ...                none
# 1  Apartment, perfect for 2 people, can accommoda...                none
# 2  Perfect, big apartment for families or groups ...                none
# 3  Santa Maria Novella, perfect apartment for fam...                none
# 4  CLEANLINESS, COMFORT and QUIETNESS!! Our stren...                none
#
#                                neighborhood_overview  \
# 0  In 10/15 minutes walking or with only one stop...
# 1  In 10/15 minutes walking you will reach the hi...
# 2  In 10/15 minutes walking you will reach the hi...
# 3  In 10/15 minutes walking or with only one stop...
# 4                                                NaN
#
#                                                notes  \
# 0                                                NaN
# 1  Da pochi mesi è attiva la nuova LINEA 2 della ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              transit access  \
# 0  We do not have private parking, but we are off...    NaN
# 1  We do not have private parking, but we are off...    NaN
# 2  We do not have private parking, but we are off...    NaN
# 3  We do not have private parking, but we are off...    NaN
# 4                                                NaN    NaN
#
#                                          interaction  \
# 0  Benedetta and Lorenzo will be happy to welcome...
# 1  Benedetta and Lorenzo will be happy to welcome...
# 2  Benedetta and Lorenzo will be happy to welcome...
# 3  Benedetta and Lorenzo will be happy to welcome...
# 4                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0  I nostri ospiti sono i benvenuti, chiediamo di...            NaN
# 1  RULES AND CONDITION(URL HIDDEN) 1. The apartme...            NaN
# 2  REGOLE E CONDIZION (Website hidden by Airbnb) ...            NaN
# 3                                                NaN            NaN
# 4  Smoking is not permitted and animals are not a...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/fd822ef3-4...
# 1         NaN  https://a0.muscache.com/im/pictures/cfa220db-5...
# 2         NaN  https://a0.muscache.com/im/pictures/31756e2d-0...
# 3         NaN  https://a0.muscache.com/im/pictures/130826/15c...
# 4         NaN  https://a0.muscache.com/im/pictures/97677826/2...
#
#    xl_picture_url  host_id                                 host_url  \
# 0             NaN    99178  https://www.airbnb.com/users/show/99178
# 1             NaN    99178  https://www.airbnb.com/users/show/99178
# 2             NaN    99178  https://www.airbnb.com/users/show/99178
# 3             NaN    99178  https://www.airbnb.com/users/show/99178
# 4             NaN    68490  https://www.airbnb.com/users/show/68490
#
#                host_name  host_since             host_location  \
# 0  Benedetta And Lorenzo  2010-03-26  Florence, Toscana, Italy
# 1  Benedetta And Lorenzo  2010-03-26  Florence, Toscana, Italy
# 2  Benedetta And Lorenzo  2010-03-26  Florence, Toscana, Italy
# 3  Benedetta And Lorenzo  2010-03-26  Florence, Toscana, Italy
# 4                Alberto  2010-01-07     Vienna, Wien, Austria
#
#                                           host_about  host_response_time  \
# 0  Hi, my name is Benedetta and together with my ...  within a few hours
# 1  Hi, my name is Benedetta and together with my ...  within a few hours
# 2  Hi, my name is Benedetta and together with my ...  within a few hours
# 3  Hi, my name is Benedetta and together with my ...  within a few hours
# 4  I am working for the United Nations in Vienna ...      within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 f
# 1               100%                   NaN                 f
# 2               100%                   NaN                 f
# 3               100%                   NaN                 f
# 4               100%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/99178/profile...
# 1  https://a0.muscache.com/im/users/99178/profile...
# 2  https://a0.muscache.com/im/users/99178/profile...
# 3  https://a0.muscache.com/im/users/99178/profile...
# 4  https://a0.muscache.com/im/users/68490/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/99178/profile...       San Jacopino
# 1  https://a0.muscache.com/im/users/99178/profile...       San Jacopino
# 2  https://a0.muscache.com/im/users/99178/profile...       San Jacopino
# 3  https://a0.muscache.com/im/users/99178/profile...       San Jacopino
# 4  https://a0.muscache.com/im/users/68490/profile...     Campo di Marte
#
#    host_listings_count  host_total_listings_count  \
# 0                  5.0                        5.0
# 1                  5.0                        5.0
# 2                  5.0                        5.0
# 3                  5.0                        5.0
# 4                  2.0                        2.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 1  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#   host_identity_verified                    street   neighbourhood  \
# 0                      t  Florence, Tuscany, Italy  Centro Storico
# 1                      t  Florence, Tuscany, Italy    San Jacopino
# 2                      t  Florence, Tuscany, Italy    San Jacopino
# 3                      t  Florence, Tuscany, Italy    San Jacopino
# 4                      f  Florence, Tuscany, Italy  Campo di Marte
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed      city    state  \
# 0         Centro Storico                           NaN  Florence  Tuscany
# 1         Centro Storico                           NaN  Florence  Tuscany
# 2         Centro Storico                           NaN  Florence  Tuscany
# 3         Centro Storico                           NaN  Florence  Tuscany
# 4         Campo di Marte                           NaN  Florence  Tuscany
#
#   zipcode    market   smart_location country_code country  latitude  \
# 0   50144  Florence  Florence, Italy           IT   Italy  43.78308
# 1   50144  Florence  Florence, Italy           IT   Italy  43.78287
# 2   50144  Florence  Florence, Italy           IT   Italy  43.78292
# 3   50144  Florence  Florence, Italy           IT   Italy  43.78150
# 4   50137  Florence  Florence, Italy           IT   Italy  43.77813
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0   11.24418                 t     Apartment  Entire home/apt             4
# 1   11.24431                 t     Apartment  Entire home/apt             3
# 2   11.24460                 t     Apartment  Entire home/apt             6
# 3   11.24507                 t     Apartment  Entire home/apt             6
# 4   11.29202                 t     Apartment  Entire home/apt             6
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.0       1.0   1.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
# 2        1.5       2.0   2.0  Real Bed
# 3        1.0       2.0   2.0  Real Bed
# 4        2.0       3.0   5.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,Internet,Wifi,"Air conditioning",Kitchen,H...          NaN   $80.00
# 1  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...          NaN   $75.00
# 2  {TV,Internet,Wifi,"Air conditioning",Kitchen,H...         47.0  $135.00
# 3  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...         42.0  $120.00
# 4  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...          NaN   $51.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $500.00       $950.00            $0.00       $20.00                2
# 1      $450.00           NaN            $0.00       $20.00                2
# 2      $800.00     $1,200.00            $0.00       $30.00                4
# 3      $750.00     $1,200.00            $0.00       $25.00                4
# 4          NaN           NaN          $500.00       $21.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $15.00               2             365                       2
# 1        $0.00               2             365                       2
# 2       $15.00               2             365                       2
# 3       $15.00               2             365                       2
# 4       $22.00               2             365                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       2                     365                     365
# 1                       2                     365                     365
# 2                       2                     365                     365
# 3                       2                     365                     365
# 4                       2                     365                     365
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     2.0                   365.0      2 weeks ago
# 1                     2.0                   365.0      5 weeks ago
# 2                     2.0                   365.0      5 weeks ago
# 3                     2.0                   365.0      6 weeks ago
# 4                     2.0                   365.0      3 weeks ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               21               47               70
# 1                t               18               48               78
# 2                t               27               57               80
# 3                t               21               44               67
# 4                t                7               15               36
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               345            2019-06-22                  0
# 1               350            2019-06-22                  3
# 2               355            2019-06-22                  0
# 3               342            2019-06-22                  2
# 4               152            2019-06-22                344
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      0          NaN         NaN                   NaN
# 1                      1   2010-09-22  2019-04-21                  93.0
# 2                      0          NaN         NaN                   NaN
# 3                      0   2011-06-28  2012-04-11                  60.0
# 4                     20   2010-05-11  2019-05-21                  96.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     NaN                        NaN                    NaN
# 1                    10.0                       10.0                   10.0
# 2                     NaN                        NaN                    NaN
# 3                    10.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                         10.0                     8.0                 10.0
# 2                          NaN                     NaN                  NaN
# 3                         10.0                     8.0                  9.0
# 4                         10.0                     9.0                 10.0
#
#   requires_license license                            jurisdiction_names  \
# 0                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
# 1                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
# 2                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
# 3                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
# 4                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
#
#   instant_bookable is_business_travel_ready cancellation_policy  \
# 0                t                        f        moderate_new
# 1                t                        f        moderate_new
# 2                t                        f        moderate_new
# 3                t                        f        moderate_new
# 4                t                        f        moderate_new
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               5
# 1                               5
# 2                               5
# 3                               5
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            5
# 1                                            5
# 2                                            5
# 3                                            5
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0                NaN
# 1                                            0               0.03
# 2                                            0                NaN
# 3                                            0               0.02
# 4                                            0               3.10

# %%
listings.at[listings['review_scores_rating'].isnull(), 'review_scores_rating'] = 0
listings.at[listings['review_scores_accuracy'].isnull(), 'review_scores_accuracy'] = 0
listings.at[listings['review_scores_cleanliness'].isnull(), 'review_scores_cleanliness'] = 0
listings.at[listings['review_scores_checkin'].isnull(), 'review_scores_checkin'] = 0
listings.at[listings['review_scores_communication'].isnull(), 'review_scores_communication'] = 0
listings.at[listings['review_scores_location'].isnull(), 'review_scores_location'] = 0
listings.at[listings['review_scores_value'].isnull(), 'review_scores_value'] = 0

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  24469  https://www.airbnb.com/rooms/24469  20190622031149   2019-06-22
# 1  24470  https://www.airbnb.com/rooms/24470  20190622031149   2019-06-22
# 2  24471  https://www.airbnb.com/rooms/24471  20190622031149   2019-06-22
# 3  24472  https://www.airbnb.com/rooms/24472  20190622031149   2019-06-22
# 4  24807  https://www.airbnb.com/rooms/24807  20190622031149   2019-06-22
#
#                                   name  \
# 0  Fortezza/City Centre Modern Apt 2+2
# 1  Fortezza/City Centre Modern Apt 2+1
# 2  Fortezza/City Centre Modern Apt 4+2
# 3  Fortezza/City Centre Modern Apt 4+2
# 4  Beautiful Apartment Florence & WIFI
#
#                                              summary  \
# 0  Apartment, perfect for 2 people, wide, bright ...
# 1  Apartment, perfect for 2 people, can accommoda...
# 2  Perfect, big apartment for families or groups ...
# 3  Santa Maria Novella, perfect apartment for fam...
# 4  CLEANLINESS, COMFORT and QUIETNESS!! Our stren...
#
#                                                space  \
# 0  Located on the first floor of a 19th century t...
# 1  Located on the first floor of a 19th century t...
# 2  Located on the first floor of a 19th century t...
# 3  Located on the first floor of a 19th century t...
# 4  It's not a case if we have some 330 five star ...
#
#                                          description experiences_offered  \
# 0  Apartment, perfect for 2 people, wide, bright ...                none
# 1  Apartment, perfect for 2 people, can accommoda...                none
# 2  Perfect, big apartment for families or groups ...                none
# 3  Santa Maria Novella, perfect apartment for fam...                none
# 4  CLEANLINESS, COMFORT and QUIETNESS!! Our stren...                none
#
#                                neighborhood_overview  \
# 0  In 10/15 minutes walking or with only one stop...
# 1  In 10/15 minutes walking you will reach the hi...
# 2  In 10/15 minutes walking you will reach the hi...
# 3  In 10/15 minutes walking or with only one stop...
# 4                                                NaN
#
#                                                notes  \
# 0                                                NaN
# 1  Da pochi mesi è attiva la nuova LINEA 2 della ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              transit access  \
# 0  We do not have private parking, but we are off...    NaN
# 1  We do not have private parking, but we are off...    NaN
# 2  We do not have private parking, but we are off...    NaN
# 3  We do not have private parking, but we are off...    NaN
# 4                                                NaN    NaN
#
#                                          interaction  \
# 0  Benedetta and Lorenzo will be happy to welcome...
# 1  Benedetta and Lorenzo will be happy to welcome...
# 2  Benedetta and Lorenzo will be happy to welcome...
# 3  Benedetta and Lorenzo will be happy to welcome...
# 4                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0  I nostri ospiti sono i benvenuti, chiediamo di...            NaN
# 1  RULES AND CONDITION(URL HIDDEN) 1. The apartme...            NaN
# 2  REGOLE E CONDIZION (Website hidden by Airbnb) ...            NaN
# 3                                                NaN            NaN
# 4  Smoking is not permitted and animals are not a...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/fd822ef3-4...
# 1         NaN  https://a0.muscache.com/im/pictures/cfa220db-5...
# 2         NaN  https://a0.muscache.com/im/pictures/31756e2d-0...
# 3         NaN  https://a0.muscache.com/im/pictures/130826/15c...
# 4         NaN  https://a0.muscache.com/im/pictures/97677826/2...
#
#    xl_picture_url  host_id                                 host_url  \
# 0             NaN    99178  https://www.airbnb.com/users/show/99178
# 1             NaN    99178  https://www.airbnb.com/users/show/99178
# 2             NaN    99178  https://www.airbnb.com/users/show/99178
# 3             NaN    99178  https://www.airbnb.com/users/show/99178
# 4             NaN    68490  https://www.airbnb.com/users/show/68490
#
#                host_name  host_since             host_location  \
# 0  Benedetta And Lorenzo  2010-03-26  Florence, Toscana, Italy
# 1  Benedetta And Lorenzo  2010-03-26  Florence, Toscana, Italy
# 2  Benedetta And Lorenzo  2010-03-26  Florence, Toscana, Italy
# 3  Benedetta And Lorenzo  2010-03-26  Florence, Toscana, Italy
# 4                Alberto  2010-01-07     Vienna, Wien, Austria
#
#                                           host_about  host_response_time  \
# 0  Hi, my name is Benedetta and together with my ...  within a few hours
# 1  Hi, my name is Benedetta and together with my ...  within a few hours
# 2  Hi, my name is Benedetta and together with my ...  within a few hours
# 3  Hi, my name is Benedetta and together with my ...  within a few hours
# 4  I am working for the United Nations in Vienna ...      within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 f
# 1               100%                   NaN                 f
# 2               100%                   NaN                 f
# 3               100%                   NaN                 f
# 4               100%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/99178/profile...
# 1  https://a0.muscache.com/im/users/99178/profile...
# 2  https://a0.muscache.com/im/users/99178/profile...
# 3  https://a0.muscache.com/im/users/99178/profile...
# 4  https://a0.muscache.com/im/users/68490/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/99178/profile...       San Jacopino
# 1  https://a0.muscache.com/im/users/99178/profile...       San Jacopino
# 2  https://a0.muscache.com/im/users/99178/profile...       San Jacopino
# 3  https://a0.muscache.com/im/users/99178/profile...       San Jacopino
# 4  https://a0.muscache.com/im/users/68490/profile...     Campo di Marte
#
#    host_listings_count  host_total_listings_count  \
# 0                  5.0                        5.0
# 1                  5.0                        5.0
# 2                  5.0                        5.0
# 3                  5.0                        5.0
# 4                  2.0                        2.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 1  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#   host_identity_verified                    street   neighbourhood  \
# 0                      t  Florence, Tuscany, Italy  Centro Storico
# 1                      t  Florence, Tuscany, Italy    San Jacopino
# 2                      t  Florence, Tuscany, Italy    San Jacopino
# 3                      t  Florence, Tuscany, Italy    San Jacopino
# 4                      f  Florence, Tuscany, Italy  Campo di Marte
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed      city    state  \
# 0         Centro Storico                           NaN  Florence  Tuscany
# 1         Centro Storico                           NaN  Florence  Tuscany
# 2         Centro Storico                           NaN  Florence  Tuscany
# 3         Centro Storico                           NaN  Florence  Tuscany
# 4         Campo di Marte                           NaN  Florence  Tuscany
#
#   zipcode    market   smart_location country_code country  latitude  \
# 0   50144  Florence  Florence, Italy           IT   Italy  43.78308
# 1   50144  Florence  Florence, Italy           IT   Italy  43.78287
# 2   50144  Florence  Florence, Italy           IT   Italy  43.78292
# 3   50144  Florence  Florence, Italy           IT   Italy  43.78150
# 4   50137  Florence  Florence, Italy           IT   Italy  43.77813
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0   11.24418                 t     Apartment  Entire home/apt             4
# 1   11.24431                 t     Apartment  Entire home/apt             3
# 2   11.24460                 t     Apartment  Entire home/apt             6
# 3   11.24507                 t     Apartment  Entire home/apt             6
# 4   11.29202                 t     Apartment  Entire home/apt             6
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.0       1.0   1.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
# 2        1.5       2.0   2.0  Real Bed
# 3        1.0       2.0   2.0  Real Bed
# 4        2.0       3.0   5.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,Internet,Wifi,"Air conditioning",Kitchen,H...          NaN   $80.00
# 1  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...          NaN   $75.00
# 2  {TV,Internet,Wifi,"Air conditioning",Kitchen,H...         47.0  $135.00
# 3  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...         42.0  $120.00
# 4  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...          NaN   $51.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $500.00       $950.00            $0.00       $20.00                2
# 1      $450.00           NaN            $0.00       $20.00                2
# 2      $800.00     $1,200.00            $0.00       $30.00                4
# 3      $750.00     $1,200.00            $0.00       $25.00                4
# 4          NaN           NaN          $500.00       $21.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $15.00               2             365                       2
# 1        $0.00               2             365                       2
# 2       $15.00               2             365                       2
# 3       $15.00               2             365                       2
# 4       $22.00               2             365                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       2                     365                     365
# 1                       2                     365                     365
# 2                       2                     365                     365
# 3                       2                     365                     365
# 4                       2                     365                     365
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     2.0                   365.0      2 weeks ago
# 1                     2.0                   365.0      5 weeks ago
# 2                     2.0                   365.0      5 weeks ago
# 3                     2.0                   365.0      6 weeks ago
# 4                     2.0                   365.0      3 weeks ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               21               47               70
# 1                t               18               48               78
# 2                t               27               57               80
# 3                t               21               44               67
# 4                t                7               15               36
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               345            2019-06-22                  0
# 1               350            2019-06-22                  3
# 2               355            2019-06-22                  0
# 3               342            2019-06-22                  2
# 4               152            2019-06-22                344
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      0          NaN         NaN                   0.0
# 1                      1   2010-09-22  2019-04-21                  93.0
# 2                      0          NaN         NaN                   0.0
# 3                      0   2011-06-28  2012-04-11                  60.0
# 4                     20   2010-05-11  2019-05-21                  96.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     0.0                        0.0                    0.0
# 1                    10.0                       10.0                   10.0
# 2                     0.0                        0.0                    0.0
# 3                    10.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          0.0                     0.0                  0.0
# 1                         10.0                     8.0                 10.0
# 2                          0.0                     0.0                  0.0
# 3                         10.0                     8.0                  9.0
# 4                         10.0                     9.0                 10.0
#
#   requires_license license                            jurisdiction_names  \
# 0                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
# 1                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
# 2                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
# 3                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
# 4                f     NaN  {Florence," IT Zip Codes"," Florence"," IT"}
#
#   instant_bookable is_business_travel_ready cancellation_policy  \
# 0                t                        f        moderate_new
# 1                t                        f        moderate_new
# 2                t                        f        moderate_new
# 3                t                        f        moderate_new
# 4                t                        f        moderate_new
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               5
# 1                               5
# 2                               5
# 3                               5
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            5
# 1                                            5
# 2                                            5
# 3                                            5
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0                NaN
# 1                                            0               0.03
# 2                                            0                NaN
# 3                                            0               0.02
# 4                                            0               3.10
